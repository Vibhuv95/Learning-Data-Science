# %%
import seaborn as sns
import numpy as np

# %%
sns.set_theme(style="dark")

# %%
x = np.array([1, 2, 3, 4, 5 ,6, 7 ,454, 234, 567, 978, 456, 45, 34 ,23, 45, 34, 45])

# %%
y = np.sin(x)

# %%
sns.lineplot(x = x, y = y)
# Out:
# <Axes: >
