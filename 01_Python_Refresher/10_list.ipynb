# %%
l = [3, 5, 23, 3]

# %%
l[0] = 4

# %%
for item in l:
    print(item)
# Out:
# 4
# 5
# 23
# 3

# %%
l
# Out:
# [4, 5, 23, 3]

# %%
l.append(9)

# %%
l
# Out:
# [4, 5, 23, 3, 9, 9, 9]

# %%
l2 = [5, 44]

# %%
l.extend(l2)

# %%
l
# Out:
# [4, 5, 23, 3, 9, 9, 9, 5, 44, 5, 44, 5, 44, 5, 44]

# %%
l.remove(44)

# %%
l.remove(5)

# %%
l
# Out:
# [4, 23, 3, 9, 9, 9, 44]

# %%
l.append(5)

# %%
l
# Out:
# [4, 23, 3, 9, 9, 9, 44, 5, 5]

# %%
l.insert(1, 290)

# %%
l
# Out:
# [4, 290, 23, 3, 9, 9, 9, 44, 5, 5]

# %%
l.index(4)
# Out:
# 0

# %%
l.sort()

# %%
l
# Out:
# [3, 4, 5, 5, 9, 9, 9, 23, 44, 290]

# %%
newl = [2, 3, 4, 4 , 567]

# %%
newl
# Out:
# [2, 3, 4, 4, 567]

# %%
n = [ 74548, 453, 533  ,45]

# %%
sorted(n)
# Out:
# [45, 453, 533, 74548]

# %%
y = [1, 2, True, False, [4, 7]]

# %%
y[4]
# Out:
# [4, 7]

# %%
y[4][1]
# Out:
# 7

# %%
if 2 in y:
    print("Yes")
# Out:
# Yes

# %%
s = "jack-basbosa-davy-william-elizabeth"

# %%
s.split("-")
# Out:
# ['jack', 'basbosa', 'davy', 'william', 'elizabeth']
