# %%
s = "Harry"

# %%
s.upper()
# Out:
# 'HARRY'

# %%
s
# Out:
# 'Harry'

# %%
s.lower()
# Out:
# 'harry'

# %%
print(f"{'python':<20}") #left alighn
print(f"{'python':>20}") #Right alighn
print(f"{'python':^20}") #center alighn
# Out:
# python
#               python
#        python
