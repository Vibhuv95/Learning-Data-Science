# %%
a = 10
b = 5

# %%
a + b
# Out:
# 15

# %%
a*b
# Out:
# 50

# %%
a/b
# Out:
# 2.0

# %%
a//b
# Out:
# 2

# %%
2**2
# Out:
# 4

# %%
2**5
# Out:
# 32

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
c = 3

# %%
a == c
# Out:
# False

# %%
a = c

# %%
a + b
# Out:
# 8

# %%
b1 = True
b2 = False

# %%
b1 and b2
# Out:
# False

# %%
b1 or b2
# Out:
# True

# %%
not b1
# Out:
# False

# %%
not b2
# Out:
# True

# %%
 a += 4

# %%
print(a)
# Out:
# 11
