# %%
name = "Harry"

# %%
name
# Out:
# 'Harry'

# %%
name.upper()
# Out:
# 'HARRY'

# %%
name.endswith("ry")
# Out:
# True

# %%
name.endswith("jerry")
# Out:
# False

# %%
name.lower()
# Out:
# 'harry'

# %%
name.count("a")
# Out:
# 1

# %%
name.count("r")
# Out:
# 2

# %%
text = "Hello World"
print(len(text))  # 11
# Out:
# 11

# %%
s = "VIbhu Gautam"

# %%
s[0:5]
# Out:
# 'VIbhu'

# %%
s[1:-1]
# Out:
# 'Ibhu Gauta'

# %%
s[1:12]
# Out:
# 'Ibhu Gautam'
