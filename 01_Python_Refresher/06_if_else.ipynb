# %%
a = 4

# %%
if(a<5):
    print("Greater")
else:
    print("Smaller")
# Out:
# Greater

# %%
a = 21
if a>50:
    print("Greater than 50")
elif a>40:
    print("Greater than 40")
elif a>30:
    print("Greater than 20")
else:
    print("Done")
# Out:
# Done

# %%
def avg( a, b):
    return (a+b)/2

# %%
avg(4, 6)
# Out:
# 5.0

# %%
def greet():
    print("Hello Good Morning.")

# %%
greet()
# Out:
# Hello Good Morning.
