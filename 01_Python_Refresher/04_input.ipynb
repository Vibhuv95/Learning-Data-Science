# %%
a = input("Enter the Value of a:")
# Out:
# Enter the Value of a: 45

# %%
b = input("Enter the value of b:")
# Out:
# Enter the value of b: 67

# %%
a + b
# Out:
# '4567'

# %%
int(a) + int(b)
# Out:
# 112

# %%
c = int(input("Enter the valueo of c"))
# Out:
# Enter the valueo of c 45

# %%
int(a) + c
# Out:
# 90
