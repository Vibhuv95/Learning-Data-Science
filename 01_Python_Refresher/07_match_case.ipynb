# %%
code = 200

# %%
match code:
    case 200:
        print("Responce OK")
        print("Good Job")
    case 400:
        print("Bad Response")
    case 404:
        print("Not Found")
    case _:
        print("Nothing Matched")
print("End of the Program.")
# Out:
# Responce OK
# Good Job
# End of the Program.
