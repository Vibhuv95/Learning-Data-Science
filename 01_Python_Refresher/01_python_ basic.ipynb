# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
name = "Vibhu"

# %%
print(name)
# Out:
# Vibhu

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(name)
# Out:
# str

# %%
a = "4565" 
b = "5677"

# %%
print("Hello World") # This line prints the HEllo World
# Out:
# Hello World

# %%
# this is a comment

# %%
name = "Cantain Jack Sparow"

# %%
type(name)
# Out:
# str

# %%
a = "50"

# %%
b = "63"

# %%
print(a + b)
# Out:
# 5063

# %%
int(a) + int(b)
# Out:
# 113
